# %% [markdown]
# <a href="https://colab.research.google.com/github/HongWonSeok/DAP__/blob/main/Final_HW_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/HongWonSeok/hairloss/main/hairlossdata.csv' , encoding='cp949')
df.head()
# Out:
#     번호   성별   세대      DNA  ... Unnamed: 48 Unnamed: 49 Unnamed: 50 Unnamed: 51
# 0  NaN  NaN  NaN    IL2RA  ...       내부적요인        정신건강        영양상태          합계
# 1  1.0   남자  20대  CC homo  ...      62.125         NaN         NaN         NaN
# 2  2.0   남자  20대  CC homo  ...          56         NaN         NaN         NaN
# 3  3.0   여자  20대  CC homo  ...       61.25         NaN         NaN         NaN
# 4  4.0   남자  20대  TT homo  ...      58.875         NaN         NaN         NaN
#
# [5 rows x 52 columns]
